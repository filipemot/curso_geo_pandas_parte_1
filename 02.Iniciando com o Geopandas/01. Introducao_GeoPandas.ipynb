# %% [markdown]
# # 01 - Introdução Geopandas

# %%
# %matplotlib inline
import geopandas as gpd

# %%
rj = gpd.read_file('shps/33MUE250GC_SIR.shp')

# %%
rj.plot(color='white', edgecolor='black', figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
from shapely.geometry import Polygon, Point, LineString, MultiPolygon

# %%
p1 = Polygon([(0, 0),(1, 0),(1, 1),(0, 1)])

g = gpd.GeoSeries(p1)
g.plot()
# Out:
# <AxesSubplot:>

# %%
p1 = Polygon([(0, 0),(1, 0),(1, 1),(0, 1)])
p2 = Polygon([(0, 0),(1, 0),(1, 1)])
g = gpd.GeoSeries([p1, p2])
g.plot(cmap="tab20")
# Out:
# <AxesSubplot:>

# %%
p1 = Polygon([(0, 0),(1, 0),(1, 1),(0, 1)])
p2 = Polygon([(0, 0),(1, 0),(1, 1)])

p3 = Polygon([(2, 0),(3, 0),(3, 1),(2, 1)])
g = gpd.GeoSeries([p1, p2, p3])
g.plot(cmap="tab20")
# Out:
# <AxesSubplot:>

# %%
p1 = Polygon([(0, 0),(1, 0),(1, 1),(0, 1)])
p2 = Polygon([(0, 0),(1, 0),(1, 1)])

p3 = Polygon([(2, 0),(3, 0),(3, 1),(2, 1)])

p4 = LineString([(0,1),(3,0),(1,1)])

g = gpd.GeoSeries([p1, p2, p3, p4])
g.plot(cmap="tab10")
# Out:
# <AxesSubplot:>

# %%
p1 = Polygon([(0, 0),(1, 0),(1, 1),(0, 1)])
p2 = Polygon([(0, 0),(1, 0),(1, 1)])

p3 = Polygon([(2, 0),(3, 0),(3, 1),(2, 1)])

p4 = LineString([(0,1),(3,0),(1,1)])

p5 = Point(0.5, 0.5)

g = gpd.GeoSeries([p1, p2, p3, p4, p5])
g.plot(cmap="tab10")
# Out:
# <AxesSubplot:>

# %%
p6 = Polygon([(1, 0),(1.5, 0.4),(2, 0)])
p7 = Polygon([(1, 1),(1.5, 0.6),(2, 1)])

# %%
p6 = Polygon([(1, 0),(1.5, 0.4),(2, 0)])
p7 = Polygon([(1, 1),(1.5, 0.6),(2, 1)])

p8 = MultiPolygon([p6, p7])

g = gpd.GeoSeries([p1, p2, p3, p4, p5, p8])
g.plot(cmap="tab10")
# Out:
# <AxesSubplot:>
